# %%
println(1.1 + 0.1)
# Out:
# 1.2000000000000002

# %%
x = 1.0
while (1.0 + x != 1.0)
    x = x / 2.0
end

EPS = 2.0 * x
println("EPS = ", EPS)
println("x = ", x)
# Out:
# EPS = 2.220446049250313e-16
# x = 1.1102230246251565e-16

# %%
# f = lambda x: (1 - np.cos(x))/x**2

f(x) = (1 .- cos.(x)) ./ (x .^ 2)

x = range(-5, 5; length=100)   # like np.linspace(-5, 5, 100)
y = f(x)

xi = (1e-5, 1e-6, 1e-7, 1e-8, 1e-9, 1e-10, 1e-11)

for v in xi
    println("f($v) = ", f(v))   # scalar evaluation
end
# Out:
# f(1.0e-5) = 0.5000000413701854
# f(1.0e-6) = 0.5000444502911705
# f(1.0e-7) = 0.4996003610813205
# f(1.0e-8) = 0.0
# f(1.0e-9) = 0.0
# f(1.0e-10) = 0.0
# f(1.0e-11) = 0.0
